# %%
# Script for prototyping data flow
from bs4 import BeautifulSoup
import requests

# Set up base info
BASE_URL_PREFIX = "https://www.spareroom.co.uk/flatshare/?offset="
BASE_URL_SUFFIX = "&search_id=962193229&sort_by=age&mode=list"

# Utility function for formatting url
def getFormedURL(prefix, suffix, page_index):
    return prefix + str(page_index) + suffix
    

# Set up request and BS object
url = getFormedURL(BASE_URL_PREFIX, BASE_URL_SUFFIX, 0)
res = requests.get(url)
if int(res.status_code) != 200:
    print("couldnt make a successful request...")
soup = BeautifulSoup(res.text, "html.parser")

# %%
# Get articles for page
def getPageListings(soup):
    return soup.find_all("li", class_="listing-result")


listings = getPageListings(soup)

# THINGS WE WANT TO PARSE PER LISTING
parseKeys = [
    "data-listing-id",
    "data-listing-title",
    "data-listing-available",
    "data-listing-status",
    "data-listing-days-old",
    "data-listing-neighbourhood",
    "data-listing-property-type",
    "data-listing-rooms-in-property",
    "data-listing-advertiser-role",
    "data-default-payment"
]

def parseListing(listing, keys):
    res = {}
    for key in keys:
        
        try:
            cleaned_key = "-".join(key.split("-")[2:])
            res[cleaned_key] = listing[key]
        except:
            continue
            
    return res


def parseListings(listings, keys):
    return list(map(lambda listing: parseListing(listing, keys), listings))

def parseListingPrices(soup):
    prices = soup.find_all("strong", class_="listingPrice")
    return list(map(lambda priceElement: priceElement.text, prices))

def parseListingLinks(soup):
    links = soup.find_all("a", class_="more desktop")
    return list(map(lambda link: link["href"], links))
    
listings = parseListings(listings, parseKeys)
prices = parseListingPrices(soup)
links = parseListingLinks(soup)

# %%
print(links[0])
# Out:
# /flatshare/fad_click.pl?fad_id=2874990&search_id=962193229&offset=0&city_id=&flatshare_type=offered&search_results=%2Fflatshare%2F%3Foffset%3D0%26search_id%3D962193229%26sort_by%3Dage%26mode%3Dlist&

# %%
# Fuse lists into single object
def mergeData(listingInfo, prices, links):

    data = []
    for index, listing in enumerate(listingInfo, 0):
        listingObject = listing
        listingObject["price"] = prices[index]
        listingObject["link"] = links[index]
        data.append(listingObject)
    
    return data

# %%
cleaned_listings = mergeData(listings, prices, links)
print(cleaned_listings[0])
# Out:
# {'id': '2874990', 'title': ' AVOID TUBE - Aldgate Zone 1 - Walk to Office', 'available': 'Available Now', 'status': 'new', 'days-old': '1', 'neighbourhood': 'Aldgate', 'property-type': 'flat', 'rooms-in-property': '3', 'advertiser-role': 'live out landlord', 'price': '£650pcm', 'link': '/flatshare/fad_click.pl?fad_id=2874990&search_id=962193229&offset=0&city_id=&flatshare_type=offered&search_results=%2Fflatshare%2F%3Foffset%3D0%26search_id%3D962193229%26sort_by%3Dage%26mode%3Dlist&'}

# %%
# Setup Data flow for all the pages of listingin Zone 1
index = 0
scraped_objects = 0

scrapedListings = []


while True:
    if failed_requests == 3:
        break
    # Set up request and BS object
    url = getFormedURL(BASE_URL_PREFIX, BASE_URL_SUFFIX, index)
    res = requests.get(url)
    if int(res.status_code) != 200:
        print("couldnt make a successful request for index %s." %str(index))
        print("retrying with next page")
    soup = BeautifulSoup(res.text, "html.parser")
    
    # Extract and parse Data
    listings = getPageListings(soup)
# Successfully scraped 10050 listings...
# Successfully scraped 10060 listings...
# Successfully scraped 10070 listings...
# Successfully scraped 10080 listings...
# Successfully scraped 10090 listings...
# Successfully scraped 10100 listings...
# Successfully scraped 10110 listings...
# Successfully scraped 10120 listings...
# Successfully scraped 10130 listings...
# Successfully scraped 10140 listings...
# Successfully scraped 10150 listings...
# Successfully scraped 10160 listings...
# Successfully scraped 10170 listings...
# Successfully scraped 10180 listings...
# Successfully scraped 10190 listings...
# Successfully scraped 10200 listings...
# Successfully scraped 10210 listings...
# Successfully scraped 10220 listings...
# Successfully scraped 10230 listings...
# Successfully scraped 10239 listings...
# Successfully scraped 10247 listings...
# Successfully scraped 10254 listings...
# Successfully scraped 10260 listings...
# Successfully scraped 10265 listings...
# Successfully scraped 10269 listings...
# Successfully scraped 10272 listings...
# Successfully scraped 10274 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# Successfully scraped 10275 listings...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378                 # Python 2.7, use buffering of HTTP responses
# --> 379                 httplib_response = conn.getresponse(buffering=True)
#     380             except TypeError:
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-133-20610d4ff105> in <module>
#      12     # Set up request and BS object
#      13     url = getFormedURL(BASE_URL_PREFIX, BASE_URL_SUFFIX, index)
# ---> 14     res = requests.get(url)
#      15     if int(res.status_code) != 200:
#      16         print("couldnt make a successful request for index %s." %str(index))
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     666
#     667         # Resolve redirects if allowed.
# --> 668         history = [resp for resp in gen] if allow_redirects else []
#     669
#     670         # Shuffle things around if there's history.
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/sessions.py in <listcomp>(.0)
#     666
#     667         # Resolve redirects if allowed.
# --> 668         history = [resp for resp in gen] if allow_redirects else []
#     669
#     670         # Shuffle things around if there's history.
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     245                     proxies=proxies,
#     246                     allow_redirects=False,
# --> 247                     **adapter_kwargs
#     248                 )
#     249
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     601                                                   timeout=timeout_obj,
#     602                                                   body=body, headers=headers,
# --> 603                                                   chunked=chunked)
#     604
#     605             # If we're going to release the connection in ``finally:``, then
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381                 # Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     302     def recv_into(self, *args, **kwargs):
#     303         try:
# --> 304             return self.connection.recv_into(*args, **kwargs)
#     305         except OpenSSL.SSL.SysCallError as e:
#     306             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:

# %%
scrapedListings[7640]
# Out:
# {'id': '14984098',
#  'title': 'Luxury Suite in Paddington',
#  'available': 'Available Now',
#  'status': 'new',
#  'days-old': '1',
#  'neighbourhood': 'Paddington',
#  'property-type': 'flat',
#  'rooms-in-property': '1',
#  'advertiser-role': 'agent',
#  'price': '£675pcm',
#  'link': '/flatshare/flatshare_detail.pl?flatshare_id=14984098&search_id=962193229&city_id=&flatshare_type=offered&search_results=%2Fflatshare%2F%3Foffset%3D731%26search_id%3D962193229%26sort_by%3Dage%26mode%3Dlist&'}

# %%
df = pd.DataFrame(scrapedListings)
df
# Out:
#          advertiser-role      available days-old        id  \
# 0      live out landlord  Available Now        1   2874990
# 1                  agent  Available Now        0  12741853
# 2                  agent  Available Now        0  15039631
# 3                  agent  Available Now        0  14138806
# 4                  agent  Available Now        0  15039616
# 5      live out landlord          9 Jun        0  15039457
# 6                  agent  Available Now        0  15039577
# 7                  agent  Available Now        0  15039394
# 8                  agent  Available Now        0  15039535
# 9                  agent  Available Now        0  15014524
# 10     live out landlord  Available Now        0  15039337
# 11     live out landlord  Available Now        1   2874990
# 12                 agent  Available Now        0  15039631
# 13                 agent  Available Now        0  14138806
# 14                 agent  Available Now        0  15039616
# 15     live out landlord          9 Jun        0  15039457
# 16                 agent  Available Now        0  15039577
# 17                 agent  Available Now        0  15039394
# 18                 agent  Available Now        0  15039535
# 19                 agent  Available Now        0  15014524
# 20     live out landlord  Available Now        0  15039337
# 21                 agent  Available Now        0  14266402
# 22     live out landlord  Available Now        1   2874990
# 23                 agent  Available Now        0  14138806
# 24                 agent  Available Now        0  15039616
# 25     live out landlord          9 Jun        0  15039457
# 26                 agent  Available Now        0  15039577
# 27                 agent  Available Now        0  15039394
# 28                 agent  Available Now        0  15039535
# 29                 agent  Available Now        0  15014524
# ...                  ...            ...      ...       ...
# 10245              agent  Available Now        2  15030184
# 10246              agent  Available Now        2  14952109
# 10247              agent  Available Now        2  15007006
# 10248  live out landlord  Available Now        2  15034375
# 10249              agent  Available Now        2  15011644
# 10250    former flatmate  Available Now        2  14782363
# 10251              agent  Available Now        2  14405824
# 10252              agent  Available Now        2  15030184
# 10253              agent  Available Now        2  14952109
# 10254  live out landlord  Available Now        2  15034375
# 10255              agent  Available Now        2  15011644
# 10256    former flatmate  Available Now        2  14782363
# 10257              agent  Available Now        2  14405824
# 10258              agent  Available Now        2  15030184
# 10259              agent  Available Now        2  14952109
# 10260              agent  Available Now        2  15011644
# 10261    former flatmate  Available Now        2  14782363
# 10262              agent  Available Now        2  14405824
# 10263              agent  Available Now        2  15030184
# 10264              agent  Available Now        2  14952109
# 10265    former flatmate  Available Now        2  14782363
# 10266              agent  Available Now        2  14405824
# 10267              agent  Available Now        2  15030184
# 10268              agent  Available Now        2  14952109
# 10269              agent  Available Now        2  14405824
# 10270              agent  Available Now        2  15030184
# 10271              agent  Available Now        2  14952109
# 10272              agent  Available Now        2  15030184
# 10273              agent  Available Now        2  14952109
# 10274              agent  Available Now        2  14952109
#
#                                                     link     neighbourhood  \
# 0      /flatshare/fad_click.pl?fad_id=2874990&search_...           Aldgate
# 1      /flatshare/flatshare_detail.pl?flatshare_id=12...            Hoxton
# 2      /flatshare/flatshare_detail.pl?flatshare_id=15...        London SW3
# 3      /flatshare/flatshare_detail.pl?flatshare_id=14...            Hoxton
# 4      /flatshare/flatshare_detail.pl?flatshare_id=15...         London W8
# 5      /flatshare/flatshare_detail.pl?flatshare_id=15...       Clerkenwell
# 6      /flatshare/flatshare_detail.pl?flatshare_id=15...       London SW1V
# 7      /flatshare/flatshare_detail.pl?flatshare_id=15...        Marylebone
# 8      /flatshare/flatshare_detail.pl?flatshare_id=15...        London NW1
# 9      /flatshare/flatshare_detail.pl?flatshare_id=15...        Marylebone
# 10     /flatshare/flatshare_detail.pl?flatshare_id=15...       London SW1E
# 10267  /flatshare/flatshare_detail.pl?flatshare_id=15...           Aldgate
# 10268  /flatshare/flatshare_detail.pl?flatshare_id=14...      Aldgate East
# 10269  /flatshare/flatshare_detail.pl?flatshare_id=14...  Liverpool Street
# 10270  /flatshare/flatshare_detail.pl?flatshare_id=15...           Aldgate
# 10271  /flatshare/flatshare_detail.pl?flatshare_id=14...      Aldgate East
# 10272  /flatshare/flatshare_detail.pl?flatshare_id=15...           Aldgate
# 10273  /flatshare/flatshare_detail.pl?flatshare_id=14...      Aldgate East
# 10274  /flatshare/flatshare_detail.pl?flatshare_id=14...      Aldgate East
#
#                     price property-type rooms-in-property     status  \
# 0                 £650pcm          flat                 3        new
# 1              \n£650pcm           flat                 5    boosted
# 2                 £400pcm          flat                 4  new today
# 3              \n£400pcm           flat                 5    boosted
# 4         £870- £1,050pcm          flat                 5  new today
# 5      \n£870- £1,050pcm           flat                 5  new today
# 6                 £500pcm          flat                 5  new today
# 7              \n£500pcm           flat                 3  new today
# 8         £950- £1,060pcm          flat                 4  new today
# 9      \n£950- £1,060pcm           flat                 2    boosted
# 10                £870pcm          flat                 1  new today
# 11                £650pcm          flat                 3        new
# 12             \n£650pcm           flat                 4  new today
# 13        £870- £1,050pcm          flat                 5    boosted
# 14     \n£870- £1,050pcm           flat                 5  new today
# 15                £500pcm          flat                 5  new today
# 16             \n£500pcm           flat                 5  new today
# 17        £950- £1,060pcm          flat                 3  new today
# 18     \n£950- £1,060pcm           flat                 4  new today
# 19                £870pcm          flat                 2    boosted
# 20             \n£870pcm           flat                 1  new today
# 21        £850- £1,270pcm          flat                 5    boosted
# 22                £650pcm          flat                 3        new
# 23             \n£650pcm           flat                 5    boosted
# 24                £500pcm          flat                 5  new today
# 25             \n£500pcm           flat                 5  new today
# 26        £950- £1,060pcm          flat                 5  new today
# 27     \n£950- £1,060pcm           flat                 3  new today
# 28                £870pcm          flat                 4  new today
# 29             \n£870pcm           flat                 2    boosted
# ...                   ...           ...               ...        ...
# 10245             £510 pw          flat                 3        new
# 10246          \n£510 pw           flat                 2        new
# 10247             £700 pw          flat                 1        new
# 10248          \n£700 pw           flat                 3        new
# 10249        £150- £220pw          flat                 1        new
# 10250     \n£150- £220pw           flat                 4        new
# 10251             £510 pw          flat                 2        new
# 10252          \n£510 pw           flat                 3        new
# 10253           £1,000pcm          flat                 2        new
# 10254        £150- £220pw          flat                 3        new
# 10255     \n£150- £220pw           flat                 1        new
# 10256             £510 pw          flat                 4        new
# 10257          \n£510 pw           flat                 2        new
# 10258           £1,000pcm          flat                 3        new
# 10259        \n£1,000pcm           flat                 2        new
# 10260             £510 pw          flat                 1        new
# 10261          \n£510 pw           flat                 4        new
# 10262           £1,000pcm          flat                 2        new
# 10263        \n£1,000pcm           flat                 3        new
# 10264          £4,300 pcm          flat                 2        new
# 10265           £1,000pcm          flat                 4        new
# 10266        \n£1,000pcm           flat                 2        new
# 10267          £4,300 pcm          flat                 3        new
# 10268       \n£4,300 pcm           flat                 2        new
# 10269          £4,300 pcm          flat                 2        new
# 10270       \n£4,300 pcm           flat                 3        new
# 10271              £214pw          flat                 2        new
# 10272              £214pw          flat                 3        new
# 10273           \n£214pw           flat                 2        new
# 10274             £800pcm          flat                 2        new
#
#                                                    title
# 0           AVOID TUBE - Aldgate Zone 1 - Walk to Office
# 1      Nice single Rm in modern Flat - Hoxton/Shoreditch
# 2                   🔷Classy Double Room in Chelsea area🔷
# 3      Modern Double in new-built Flat - Hoxton/Shore...
# 4               🏢Special Double Room in Kensington area🏢
# 5              Bright double room in friendly clean flat
# 6                🌅En-suite Double Room in Victoria area🌅
# 7                                🔵 Promotion! Marylebone
# 8             🌇Elegant Double Room in Baker Street area🌇
# 9                               Amazing Rooms Marylebone
# 10     Large Studio 3' walk to Buckingham Pal. & Vict...
# 11          AVOID TUBE - Aldgate Zone 1 - Walk to Office
# 12                  🔷Classy Double Room in Chelsea area🔷
# 13     Modern Double in new-built Flat - Hoxton/Shore...
# 14              🏢Special Double Room in Kensington area🏢
# 15             Bright double room in friendly clean flat
# 16               🌅En-suite Double Room in Victoria area🌅
# 17                               🔵 Promotion! Marylebone
# 18            🌇Elegant Double Room in Baker Street area🌇
# 19                              Amazing Rooms Marylebone
# 20     Large Studio 3' walk to Buckingham Pal. & Vict...
# 21       Beautiful Double Rooms in Central London - A104
# 22          AVOID TUBE - Aldgate Zone 1 - Walk to Office
# 23     Modern Double in new-built Flat - Hoxton/Shore...
# 24              🏢Special Double Room in Kensington area🏢
# 25             Bright double room in friendly clean flat
# 26               🌅En-suite Double Room in Victoria area🌅
# 27                               🔵 Promotion! Marylebone
# 28            🌇Elegant Double Room in Baker Street area🌇
# 29                              Amazing Rooms Marylebone
# ...                                                  ...
# 10245  Couple Room ALDGATE - Discoutned Price Now - H...
# 10246                      Double Room in Aldgate East!!
# 10247            Luxury One Bed Flat at Liverpool Street
# 10248                     Rooms available in Vauxhall!!!
# 10249              Luxury Studio in Tower Hill for Rent!
# 10250              Large Modern New Double Ensuite Room
# 10251                        Brand new two bed for rent
# 10252  Couple Room ALDGATE - Discoutned Price Now - H...
# 10253                      Double Room in Aldgate East!!
# 10254                     Rooms available in Vauxhall!!!
# 10255              Luxury Studio in Tower Hill for Rent!
# 10256              Large Modern New Double Ensuite Room
# 10257                        Brand new two bed for rent
# 10258  Couple Room ALDGATE - Discoutned Price Now - H...
# 10259                      Double Room in Aldgate East!!
# 10260              Luxury Studio in Tower Hill for Rent!
# 10261              Large Modern New Double Ensuite Room
# 10262                        Brand new two bed for rent
# 10263  Couple Room ALDGATE - Discoutned Price Now - H...
# 10264                      Double Room in Aldgate East!!
# 10265              Large Modern New Double Ensuite Room
# 10266                        Brand new two bed for rent
# 10267  Couple Room ALDGATE - Discoutned Price Now - H...
# 10268                      Double Room in Aldgate East!!
# 10269                        Brand new two bed for rent
# 10270  Couple Room ALDGATE - Discoutned Price Now - H...
# 10271                      Double Room in Aldgate East!!
# 10272  Couple Room ALDGATE - Discoutned Price Now - H...
# 10273                      Double Room in Aldgate East!!
# 10274                      Double Room in Aldgate East!!
#
# [10275 rows x 11 columns]

# %%
df.to_csv("data/listings/raw")
